# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you read the <a href="../README.md">README</a>? Many common questions are answered here!<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.9)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.9)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.
#
# Having problems with missing Python versions in that list? Have you ever used Anaconda before? It might be interferring. Quit Cursor, bring up a new command line, and make sure that your Anaconda environment is deactivated:
# `conda deactivate`
# And if you still have any problems with conda and python versions, it's possible that you will need to run this too:
# `conda config --set auto_activate_base false`
# and then from within the Agents directory, you should be able to run `uv python list` and see the Python 3.12 version.

# %%
# First let's do an import. If you get an Import Error, double check that your Kernel is correct..

from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables
# If this returns false, see the next cell!

load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Wait, did that just output `False`??
#
# If so, the most common reason is that you didn't save your `.env` file after adding the key! Be sure to have saved.
#
# Also, make sure the `.env` file is named precisely `.env` and is in the project root directory (`agents`)
#
# By the way, your `.env` file should have a stop symbol next to it in Cursor on the left, and that's actually a good thing: that's Cursor saying to you, "hey, I realize this is a file filled with secret information, and I'm not going to send it to an external AI to suggest changes, because your keys should not be shown to anyone else."

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Final reminders</h2>
#             <span style="color:#ff7800;">1. If you're not confident about Environment Variables or Web Endpoints / APIs, please read Topics 3 and 5 in this <a href="../guides/04_technical_foundations.ipynb">technical foundations guide</a>.<br/>
#             2. If you want to use AIs other than OpenAI, like Gemini, DeepSeek or Ollama (free), please see the first section in this <a href="../guides/09_ai_apis_and_ollama.ipynb">AI APIs guide</a>.<br/>
#             3. If you ever get a Name Error in Python, you can always fix it immediately; see the last section of this <a href="../guides/06_python_foundations.ipynb">Python Foundations guide</a> and follow both tutorials and exercises.<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Check the key - if you're not using OpenAI, check whichever key you're using! Ollama doesn't need a key.

import os
openai_api_key = os.getenv('OPENAI_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# OpenAI API Key exists and begins sk-proj-

# %%
# And now - the all important import statement
# If you get an import error - head over to troubleshooting in the Setup folder
# Even for other LLM providers like Gemini, you still use this OpenAI import - see Guide 9 for why

from openai import OpenAI

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder (guide 6)!
# If you get a NameError - head over to the guides folder (guide 6)to learn about NameErrors - always instantly fixable
# If you're not using OpenAI, you just need to slightly modify this - precise instructions are in the AI APIs guide (guide 9)

openai = OpenAI()

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", "content": "What is 2+2?"}]

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 4.1 nano, the incredibly cheap model
# The APIs guide (guide 9) has exact instructions for using even cheaper or free alternatives to OpenAI
# If you get a NameError, head to the guides folder (guide 6) to learn about NameErrors - always instantly fixable

response = openai.chat.completions.create(
    model="gpt-4.1-nano",
    messages=messages
)

print(response.choices[0].message.content)

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
# ask it - this uses GPT 4.1 mini, still cheap but more powerful than nano

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

question = response.choices[0].message.content

print(question)
# Out:
# If two trains start from opposite ends of a 600-mile track heading toward each other, one traveling at 60 mph and the other at 90 mph, a bird starts flying from the front of the slower train toward the faster train at 120 mph. When the bird reaches the faster train, it immediately turns around and flies back to the slower train, continuing this back-and-forth flight until the trains collide. How many miles does the bird travel in total?

# %%
# form a new messages list
messages = [{"role": "user", "content": question}]

# %%
# Ask it again

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

answer = response.choices[0].message.content
print(answer)
# Out:
# Let's analyze the problem step-by-step:
#
# ---
#
# ### Problem Summary:
# - Two trains start from opposite ends of a 600-mile track, heading toward each other.
# - Train A speed = 60 mph (slower train)
# - Train B speed = 90 mph (faster train)
# - A bird starts flying from the front of the slower train towards the faster train at 120 mph.
# - When the bird reaches the faster train, it immediately turns around and flies back to the slower train.
# - This continues back and forth until the trains collide.
# - Find the total distance the bird travels.
#
# ---
#
# ### Step 1: Find the time until the trains collide
#
# The trains are moving towards each other on a 600-mile track.
#
# - Relative speed of the trains = 60 mph + 90 mph = 150 mph
# - Time until collision = Distance / Relative speed = 600 miles / 150 mph = 4 hours
#
# ---
#
# ### Step 2: How far does the bird travel?
#
# The bird continuously flies back and forth at 120 mph for the entire duration before the trains collide.
#
# - Total time the bird flies = 4 hours (same as the time until collision)
# - Distance flown by the bird = speed × time = 120 mph × 4 hours = 480 miles
#
# ---
#
# ### **Answer:**
#
# \[
# \boxed{480 \text{ miles}}
# \]
#
# The bird travels a total of **480 miles**.

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# Let's analyze the problem step-by-step:
#
# ---
#
# ### Problem Summary:
# - Two trains start from opposite ends of a 600-mile track, heading toward each other.
# - Train A speed = 60 mph (slower train)
# - Train B speed = 90 mph (faster train)
# - A bird starts flying from the front of the slower train towards the faster train at 120 mph.
# - When the bird reaches the faster train, it immediately turns around and flies back to the slower train.
# - This continues back and forth until the trains collide.
# - Find the total distance the bird travels.
#
# ---
#
# ### Step 1: Find the time until the trains collide
#
# The trains are moving towards each other on a 600-mile track.
#
# - Relative speed of the trains = 60 mph + 90 mph = 150 mph
# - Time until collision = Distance / Relative speed = 600 miles / 150 mph = 4 hours
#
# ---
#
# ### Step 2: How far does the bird travel?
#
# The bird continuously flies back and forth at 120 mph for the entire duration before the trains collide.
#
# - Total time the bird flies = 4 hours (same as the time until collision)
# - Distance flown by the bird = speed × time = 120 mph × 4 hours = 480 miles
#
# ---
#
# ### **Answer:**
#
# \[
# \boxed{480 \text{ miles}}
# \]
#
# The bird travels a total of **480 miles**.

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
from IPython.display import Markdown, display

# %%
# First create the messages:

messages = [{"role": "user", "content": "I want you to pick up a business area that might be of high importance in the coming five years. Please respond only with the business area and a line of explanation for why you chose it."}]

# Then make the first call:

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

# Then read the business idea:

business_idea = response.choices[0].message.content

print(display(Markdown(business_idea)))

# And repeat! In the next message, include the business idea within the message
# Out:
# Sustainable energy solutions—because the global shift towards reducing carbon emissions and combating climate change will drive massive demand for clean, renewable energy technologies.
# None

# %%
question = f"This was the business idea proposed in the earlier message: {business_idea}. Please propose a pain-point in this industry related to the business idea and a line of explanation for why you chose it, what is its importance, and why it is a good candidate to provide an agentic solution for."
message1 = [{"role": "user", "content": question}]

response1 = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=message1
)

pain_point = response1.choices[0].message.content

print(display(Markdown(pain_point)))
# Out:
# **Pain-point:** High upfront costs and complex integration of renewable energy systems for residential and small commercial users.
#
# **Explanation:**
# I chose this pain-point because while the demand for sustainable energy technologies is growing rapidly, one of the main barriers to widespread adoption—especially among homeowners and small businesses—is the significant initial investment in equipment like solar panels, batteries, and inverters, combined with the technical complexity of integrating these systems efficiently into existing electrical setups. This is important because these groups represent a large market segment that can drive extensive adoption if the financial and technical hurdles are lowered.
#
# It is a good candidate for an agentic solution (e.g., an AI-based platform or intelligent advisory system) because such a solution can personalize financing options, optimize system design, predict energy generation and savings, and provide step-by-step guidance for installation and maintenance. This reduces friction, uncertainty, and risk for end users, accelerating their transition to clean energy and expanding the overall market.
# None

# %%
question2 = f"This was the pain point and its explanation related to the business idea ({business_idea}): {pain_point}. Now based on this pain-point, suggest an elaborate agentic AI solution that is both, effective and feasible."
message2 = [{"role": "user", "content": question2}]

response2 = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=message2
)

solution = response2.choices[0].message.content

print(display(Markdown(solution)))
# Out:
# Certainly! Building on the pain point of **high upfront costs and complex integration** for residential and small commercial renewable energy systems, here’s an elaborate agentic AI solution designed to be both effective and feasible:
#
# ---
#
# ### Agentic AI Solution: **CleanEnergySmart™ — An Intelligent Renewable Energy Advisory and Management Platform**
#
# ---
#
# #### **Core Objectives:**
#
# - **Reduce upfront cost barriers**
# - **Simplify technical design and integration**
# - **Enhance user confidence via personalized insights**
# - **Facilitate smooth installation and ongoing maintenance**
# - **Deliver measurable ROI and sustainability metrics**
#
# ---
#
# ### 1. **Personalized Financial & Incentive Optimization Module**
#
# - **AI-Powered Financing Advisor:** The platform assesses the user’s financial profile, credit score, and energy needs to curate personalized financing solutions—such as loans, leases, power purchase agreements (PPAs), or pay-as-you-go models.
# - **Dynamic Incentive Aggregator:** Continuously scrapes government, municipal, and utility rebate programs and tax credits from multiple jurisdictions and matches users with all applicable incentives.
# - **Cost-Benefit Forecasting:** Provides real-time, user-specific ROI projections over various financing scenarios, showing savings on utility bills vs. investment cost and payback period.
#
# *Feasibility:* Integrates existing open financial APIs, credit scoring services, and public datasets on renewable energy incentives.
#
# ---
#
# ### 2. **AI-Driven System Design & Integration Optimizer**
#
# - **Site Assessment via Remote Sensing & Computer Vision:** Users upload photos, or the system leverages satellite imagery and 3D modeling to analyze roof size, shading, orientation, and other site parameters.
# - **Load & Usage Pattern Learning:** Integrates smart meter data (or user input) to learn household/business energy consumption patterns to size solar panels, batteries, and inverters optimally.
# - **Hybrid System Simulation:** AI simulates various system configurations (e.g., solar-only, solar + battery, microgrid options) and predicts energy generation, storage cycles, and grid interactions.
# - **Compatibility & Integration Checker:** Evaluates existing electrical infrastructure and compatibility with proposed equipment, anticipating integration challenges early.
#
# *Feasibility:* Uses established computer vision libraries, energy modeling algorithms, and integration with smart meter IoT devices.
#
# ---
#
# ### 3. **Step-by-Step Intelligent Installation & Commissioning Guide**
#
# - **AI-Powered Virtual Assistant:** Guides users and certified installers through the installation process with tailored instructions, checklists, and real-time troubleshooting.
# - **AR (Augmented Reality) Interface:** Optional feature to overlay installation guidance and wiring diagrams onto the physical site via a smartphone or AR glasses.
# - **Scheduling & Coordination:** Coordinates between multiple stakeholders—installers, equipment suppliers, inspectors—with automated reminders and document management.
#
# *Feasibility:* Builds on existing AR toolkits and chatbot technologies; requires partnerships with installation professionals.
#
# ---
#
# ### 4. **Ongoing AI Operations & Maintenance Manager**
#
# - **Predictive Maintenance:** Continuously monitors system performance via IoT sensors and weather forecasts, predicting potential faults before failure.
# - **Energy Usage & Savings Analytics:** Provides users with intuitive dashboards showing savings, emissions avoided, and real-time energy generation vs. consumption.
# - **Automated Support & Troubleshooting:** Intelligent chatbot for FAQs and troubleshooting common issues, escalating to human support if needed.
#
# *Feasibility:* Uses IoT monitoring and machine learning anomaly detection models already proven in industrial applications.
#
# ---
#
# ### 5. **Community & Seller Marketplace**
#
# - **User-to-User Second-Hand Equipment Exchange:** Helps users upgrade systems affordably by buying/selling certified used equipment.
# - **Local Professional Network:** AI matches users with vetted local installers and financiers based on project requirements and performance ratings.
# - **Crowd-Investment & Co-Ownership Options:** Facilitates group financing models for neighborhoods or small businesses to share renewable energy infrastructure.
#
# *Feasibility:* Marketplace platforms exist in related sectors; AI matchmaking algorithms are mature.
#
# ---
#
# ### **Why This Solution is Effective:**
#
# - **Addresses Financial and Technical Barriers in Tandem:** Instead of tackling just one aspect, CleanEnergySmart™ holistically removes friction along the full customer journey.
# - **Personalization & Predictive Insights:** Custom system designs and precise savings forecasts build user trust and reduce perceived risk.
# - **Empowers Users & Installers:** AI acts as a digital guide, democratizing technical knowledge.
# - **Scalability & Adaptability:** Modular AI components can expand into new regions or support emerging technologies (e.g., EV chargers, smart thermostats).
#
# ---
#
# ### **Feasibility Considerations:**
#
# - **Data Availability:** Many datasets needed (solar irradiance, energy prices, incentives) are open or purchasable. User-provided data and IoT devices supplement.
# - **Existing Technologies:** AI models for financial advice, computer vision, and energy forecasting are mature and can be customized.
# - **Incremental Rollout:** Start with pilot regions and focus on solar+battery systems, then expand to other renewables and larger commercial setups.
# - **Partnership Opportunities:** Collaborations with financiers, local governments, utilities, and hardware manufacturers de-risk development.
#
# ---
#
# ### Summary
#
# CleanEnergySmart™ leverages advanced AI to turn a complex, costly transition into a guided, financially viable, and confidence-inspiring journey for residential and small commercial users. By simultaneously optimizing financing, system design, installation, and ongoing care—with community and marketplace components—it unlocks a wide customer base critical to rapid scaling of sustainable energy solutions.
#
# ---
#
# If you’d like, I can also help outline a phased development plan, required datasets/APIs, or mock up user experience flows for CleanEnergySmart™.
# None
